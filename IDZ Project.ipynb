# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data =pd.read_excel("D:\Python\Python38\python_practise\IDZ Digital data analyst.xls")

# %%
data.head()
# Out:
#   First Name  Last  Name  Gender   Age       Occupation   Salary  \
# 0      Jacob    Robinson    Male    58            Lawer     6779
# 1      Grace      Taylor  Female    36          Insurer     4466
# 2    Charlie      Wilson    Male    58  Aeroplane Pilot     5786
# 3    Vanessa     Farrell  Female    23            Lawer     3403
# 4     Fenton    Harrison    Male    21        Architect      693
#
#    Marital Status   No. of Children
# 0         Married                 2
# 1         Married                 1
# 2          Single                 0
# 3         Married                 2
# 4         Married                 0

# %%
print('Total number of students:',len(data))
# Out:
# Total number of students: 1000

# %%
data[' Salary'].describe()
# Out:
# count     1000.000000
# mean      5303.460000
# std       2761.864336
# min        520.000000
# 25%       2955.500000
# 50%       5228.000000
# 75%       7814.750000
# max      10000.000000
# Name:  Salary, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   First Name        1000 non-null   object
#  1    Last  Name       1000 non-null   object
#  2    Gender           1000 non-null   object
#  3    Age              1000 non-null   int64
#  4    Occupation       1000 non-null   object
#  5    Salary           1000 non-null   int64
#  6    Marital Status   1000 non-null   object
#  7    No. of Children  1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.columns
# Out:
# Index(['First Name', ' Last  Name', ' Gender', ' Age', ' Occupation',
#        ' Salary', ' Marital Status', ' No. of Children'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age        Salary   No. of Children
# count  1000.000000   1000.000000       1000.000000
# mean     39.536000   5303.460000          2.447000
# std      12.477275   2761.864336          1.703553
# min      18.000000    520.000000          0.000000
# 25%      29.000000   2955.500000          1.000000
# 50%      40.000000   5228.000000          2.000000
# 75%      50.000000   7814.750000          4.000000
# max      60.000000  10000.000000          5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   First Name        1000 non-null   object
#  1    Last  Name       1000 non-null   object
#  2    Gender           1000 non-null   object
#  3    Age              1000 non-null   int64
#  4    Occupation       1000 non-null   object
#  5    Salary           1000 non-null   int64
#  6    Marital Status   1000 non-null   object
#  7    No. of Children  1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.columns
# Out:
# Index(['First Name', ' Last  Name', ' Gender', ' Age', ' Occupation',
#        ' Salary', ' Marital Status', ' No. of Children'],
#       dtype='object')

# %%
data.isnull().any()
# Out:
# First Name          False
#  Last  Name         False
#  Gender             False
#  Age                False
#  Occupation         False
#  Salary             False
#  Marital Status     False
#  No. of Children    False
# dtype: bool

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data.iplot()
# Out:
# <div>                            <div id="5d008b9f-4f95-46e8-903b-9895552721ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#Data Visualization

# %%
sns.heatmap(data.isnull(),cmap="rainbow",yticklabels=False)    # To check any null values present in dataset pictorially
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.isnull(),cmap="viridis",yticklabels=False)    # Map color - viridis
# Out:
# <AxesSubplot:>
